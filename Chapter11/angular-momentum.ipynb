# %% [markdown]
# # Angular Momentum
#
# ## Rolling Motion

# %% [markdown]
# ## Angular Momentum

# %% [markdown]
# ## Conservation of Angular Momentum

# %% [markdown]
# ## Precession of a Gyroscope

# %% [markdown]
# ## In-class Problems
#
# ### Part I
#
#
# ### Part II

# %% [markdown]
# ## Homework
#
# ### Conceptual Problems
#
# ### Quantitative Problems
